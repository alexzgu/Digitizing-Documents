# %%
# below are the results of the model
results = [
    ('img_1.jpg', 0.37215589096643387),
    ('img_2.jpg', 0.17262881522809326),
    ('img_3.jpg', 0.3975993998499625),
    ('img_4.jpg', 0.4133993148077655),
    ('img_5.jpg', 0.44095216085047373),
    ('img_6.jpg', 0.45629370629370625),
    ('img_7.jpg', 0.4462650602409639),
    ('img_8.jpg', 0.4658273381294964),
    ('img_9.jpg', 0.4423748544819558),
    ('img_10.jpg', 0.3675777568331763),
    ('img_11.jpg', 0.5429061784897025),
    ('img_12.jpg', 0.6772546795235395),
    ('img_13.jpg', 0.7890698109676212),
    ('img_14.jpg', 0.7046545606345231),
    ('img_15.jpg', 0.8258513931888545),
    ('img_16.jpg', 0.8034360788276907),
    ('img_17.jpg', 0.505859375),
    ('img_18.jpg', 0.7318811881188119),
    ('img_19.jpg', 0.8352849336455894),
    ('img_20.jpg', 0.7602427921092565),
    ('img_21.jpg', 0.6798722044728435),
    ('img_22.jpg', 0.7043756670224119),
    ('img_23.jpg', 0.6697345132743363),
    ('img_24.jpg', 0.812206572769953),
    ('img_25.jpg', 0.8178438661710037),
    ('img_26.jpg', 0.9276437847866419),
    ('img_27.jpg', 0.9380413057961359),
    ('img_28.jpg', 0.8656447249774571),
    ('img_29.jpg', 0.525462962962963),
    ('img_30.jpg', 0.41516639388979815),
    ('img_31.jpg', 0.426829268292683),
    ('img_32.jpg', 0.4246153846153846),
    ('img_33.jpg', 0.43080625752105894),
    ('img_34.jpg', 0.43146997929606623),
    ('img_35.jpg', 0.4350097975179621),
    ('img_36.jpg', 0.43441064638783267),
    ('img_37.jpg', 0.43681085665818487),
    ('img_38.jpg', 0.4059121994264284),
    ('img_39.jpg', 0.4254041570438799),
    ('img_40.jpg', 0.4161462979482605)
    ]

# %%
numbers = []
for img_dir, similarity_score in results:
  numbers.append(similarity_score)

# %%
numbers
# Out:
# [0.37215589096643387,
#  0.17262881522809326,
#  0.3975993998499625,
#  0.4133993148077655,
#  0.44095216085047373,
#  0.45629370629370625,
#  0.4462650602409639,
#  0.4658273381294964,
#  0.4423748544819558,
#  0.3675777568331763,
#  0.5429061784897025,
#  0.6772546795235395,
#  0.7890698109676212,
#  0.7046545606345231,
#  0.8258513931888545,
#  0.8034360788276907,
#  0.505859375,
#  0.7318811881188119,
#  0.8352849336455894,
#  0.7602427921092565,
#  0.6798722044728435,
#  0.7043756670224119,
#  0.6697345132743363,
#  0.812206572769953,
#  0.8178438661710037,
#  0.9276437847866419,
#  0.9380413057961359,
#  0.8656447249774571,
#  0.525462962962963,
#  0.41516639388979815,
#  0.426829268292683,
#  0.4246153846153846,
#  0.43080625752105894,
#  0.43146997929606623,
#  0.4350097975179621,
#  0.43441064638783267,
#  0.43681085665818487,
#  0.4059121994264284,
#  0.4254041570438799,
#  0.4161462979482605]

# %% [markdown]
# Data Visualization

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.hist(numbers,bins=20)

plt.title('Distribution of Similarity Scores')
plt.xlabel('Similarity Score')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Descriptive Statistics

# %%
import pandas as pd
import numpy as np

# %%
data = np.array(numbers)
data = pd.Series(data)

# %%
data.describe()
# Out:
# count    40.000000
# mean      0.569373
# std       0.192316
# min       0.172629
# 25%       0.426473
# 50%       0.461061
# 75%       0.738972
# max       0.938041
# dtype: float64
